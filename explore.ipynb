# %%
x = 10
y = 5
x + y * 2
# Out:
# 20

# %%
name = "Lina"
age = 17 

print("My name is", name)
print("Iam", age, "years old")
# Out:
# My name is Lina
# Iam 17 years old

# %%
age = 17

if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers = [10, 20, 30, 40, 50]

for number in numbers:
    print(number)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# # Exploring Python expressions
# Notes for Lab 1.
